# %%
import requests
import json
import os
from pprint import pprint 
import sklearn as sk
import pandas as pd
#from sklearn import naive_bayes

# %%
url = "https://earthquake.usgs.gov/fdsnws/event/1/[query[format=geojson]]"
data_url = "https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2014-01-01&endtime=2014-01-02&eventtype=earthquake"
output_path = os.path.join("/images/")
response = requests.get(data_url)
data = response.json()

# %%
# print data to see columns and features

pprint(data)
# Out:
# {'bbox': [-179.688, -56.1218, -2.884, 167.8106, 64.8102, 582.05],
#  'features': [{'geometry': {'coordinates': [-116.7776667, 33.6633333, 11.008],
#                             'type': 'Point'},
#                'id': 'ci11408890',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '11408890',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci11408890&format=geojson',
#                               'dmin': 0.06729,
#                               'felt': None,
#                               'gap': 51,
#                               'ids': ',ci11408890,',
#                               'mag': 1.29,
#                               'magType': 'ml',
#                               'mmi': None,
#                               'net': 'ci',
#                               'nst': 39,
#                               'place': '10km SSW of Idyllwild, CA',
#                               'rms': 0.09,
#                               'sig': 26,
#                               'sources': ',ci,',
#                               'status': 'reviewed',
#                               'time': 1388620296020,
#                               'title': 'M 1.3 - 10km SSW of Idyllwild, CA',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',cap,focal-mechanism,general-link,geoserve,nearby-cities,origin,phase-data,scitech-link,',
#                               'tz': -480,
#                               'updated': 1457728844428,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci11408890'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-151.6459, 63.102, 14.1],
#                             'type': 'Point'},
#                'id': 'ak01421ig3u',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '01421ig3u',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak01421ig3u&format=geojson',
#                               'dmin': None,
#                               'felt': None,
#                               'gap': None,
#                               'ids': ',ak10992887,ak01421ig3u,',
#                               'mag': 1.1,
#                               'magType': 'ml',
#                               'mmi': None,
#                               'net': 'ak',
#                               'nst': None,
#                               'place': '117km NW of Talkeetna, Alaska',
#                               'rms': 0.57,
#                               'sig': 19,
#                               'sources': ',ak,ak,',
#                               'status': 'reviewed',
#                               'time': 1388620046501,
#                               'title': 'M 1.1 - 117km NW of Talkeetna, Alaska',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',associate,geoserve,nearby-cities,origin,phase-data,tectonic-summary,',
#                               'tz': -540,
#                               'updated': 1558392330681,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak01421ig3u'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-150.0165, 61.4581, 44.6],
#                             'type': 'Point'},
#                'id': 'ak01421i2zj',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '01421i2zj',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak01421i2zj&format=geojson',
#                               'dmin': None,
#                               'felt': None,
#                               'gap': None,
#                               'ids': ',ak10934318,ak01421i2zj,',
#                               'mag': 1.2,
#                               'magType': 'ml',
#                               'mmi': None,
#                               'net': 'ak',
#                               'nst': None,
#                               'place': '6km SSW of Big Lake, Alaska',
#                               'rms': 0.47,
#                               'sig': 22,
#                               'sources': ',ak,ak,',
#                               'status': 'reviewed',
#                               'time': 1388619956476,
#                               'title': 'M 1.2 - 6km SSW of Big Lake, Alaska',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',associate,cap,geoserve,nearby-cities,origin,phase-data,tectonic-summary,',
#                               'tz': -540,
#                               'updated': 1558392330249,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak01421i2zj'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-150.8276, 62.7884, 87.6],
#                             'type': 'Point'},
#                'id': 'ak01421heui',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '01421heui',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak01421heui&format=geojson',
#                               'dmin': None,
#                               'felt': None,
#                               'gap': None,
#                               'ids': ',ak10992885,ak01421heui,',
#                               'mag': 1.4,
#                               'magType': 'ml',
#                               'mmi': None,
#                               'net': 'ak',
#                               'nst': None,
#                               'place': '63km NW of Talkeetna, Alaska',
#                               'rms': 0.35,
#                               'sig': 30,
#                               'sources': ',ak,ak,',
#                               'status': 'reviewed',
#                               'time': 1388619763623,
#                               'title': 'M 1.4 - 63km NW of Talkeetna, Alaska',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',associate,geoserve,nearby-cities,origin,phase-data,tectonic-summary,',
#                               'tz': -540,
#                               'updated': 1558392329762,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak01421heui'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-71.621, -29.888, 40],
#                             'type': 'Point'},
#                'id': 'usc000mnnn',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': 'c000mnnn',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usc000mnnn&format=geojson',
#                               'dmin': None,
#                               'felt': None,
#                               'gap': None,
#                               'ids': ',usc000mnnn,',
#                               'mag': 4,
#                               'magType': 'ml',
#                               'mmi': None,
#                               'net': 'us',
#                               'nst': None,
#                               'place': '27km WNW of Coquimbo, Chile',
#                               'rms': 3.09,
#                               'sig': 246,
#                               'sources': ',us,',
#                               'status': 'reviewed',
#                               'time': 1388619735000,
#                               'title': 'M 4.0 - 27km WNW of Coquimbo, Chile',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',general-link,geoserve,nearby-cities,origin,phase-data,tectonic-summary,',
#                               'tz': -300,
#                               'updated': 1394151954000,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/usc000mnnn'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-122.7839966, 38.8071671, 0.013],
#                             'type': 'Point'},
#                'id': 'nc72134466',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '72134466',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc72134466&format=geojson',
#                               'dmin': 0.007207,
#                               'felt': None,
#                               'gap': 90,
#                               'ids': ',nc72134466,',
#                               'mag': 0.53,
#                               'magType': 'md',
#                               'mmi': None,
#                               'net': 'nc',
#                               'nst': 8,
#                               'place': '4km NW of The Geysers, California',
#                               'rms': 0.03,
#                               'sig': 4,
#                               'sources': ',nc,',
#                               'status': 'automatic',
#                               'time': 1388619644020,
#                               'title': 'M 0.5 - 4km NW of The Geysers, '
#                                        'California',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#                               'tz': -480,
#                               'updated': 1486063047447,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc72134466'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-118.8948333, 37.6433333, -0.446],
#                             'type': 'Point'},
#                'id': 'nc72134461',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '72134461',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc72134461&format=geojson',
#                               'dmin': 0.001802,
#                               'felt': None,
#                               'gap': 133,
#                               'ids': ',nc72134461,',
#                               'mag': 0.7,
#                               'magType': 'md',
#                               'mmi': None,
#                               'net': 'nc',
#                               'nst': 16,
#                               'place': '6km E of Mammoth Lakes, California',
#                               'rms': 0.08,
#                               'sig': 8,
#                               'sources': ',nc,',
#                               'status': 'reviewed',
#                               'time': 1388619483870,
#                               'title': 'M 0.7 - 6km E of Mammoth Lakes, '
#                                        'California',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#                               'tz': -480,
#                               'updated': 1486063041500,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc72134461'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-116.562, 33.5175, 8.148],
#                             'type': 'Point'},
#                'id': 'ci11408882',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '11408882',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci11408882&format=geojson',
#                               'dmin': 0.04045,
#                               'felt': None,
#                               'gap': 92,
#                               'ids': ',ci11408882,',
#                               'mag': 0.47,
#                               'magType': 'ml',
#                               'mmi': None,
#                               'net': 'ci',
#                               'nst': 17,
#                               'place': '11km ESE of Anza, CA',
#                               'rms': 0.09,
#                               'sig': 3,
#                               'sources': ',ci,',
#                               'status': 'reviewed',
#                               'time': 1388619402290,
#                               'title': 'M 0.5 - 11km ESE of Anza, CA',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',cap,general-link,geoserve,nearby-cities,origin,phase-data,scitech-link,',
#                               'tz': -480,
#                               'updated': 1457688589278,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci11408882'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-118.4646, 38.5678, 8.7],
#                             'type': 'Point'},
#                'id': 'nn00557597',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '00557597',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nn00557597&format=geojson',
#                               'dmin': 0.075,
#                               'felt': None,
#                               'gap': 155.68,
#                               'ids': ',nn00557597,',
#                               'mag': 0.6,
#                               'magType': 'ml',
#                               'mmi': None,
#                               'net': 'nn',
#                               'nst': 5,
#                               'place': 'Nevada',
#                               'rms': 0.1066,
#                               'sig': 6,
#                               'sources': ',nn,',
#                               'status': 'reviewed',
#                               'time': 1388619146923,
#                               'title': 'M 0.6 - Nevada',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',origin,phase-data,',
#                               'tz': None,
#                               'updated': 1530313185339,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00557597'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-176.8207, -23.9576, 219.29],
#                             'type': 'Point'},
#                'id': 'usb000m2w9',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': 'b000m2w9',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usb000m2w9&format=geojson',
#                               'dmin': 5.358,
#                               'felt': None,
#                               'gap': 136,
#                               'ids': ',usb000m2w9,',
#                               'mag': 4.2,
#                               'magType': 'mb',
#                               'mmi': None,
#                               'net': 'us',
#                               'nst': None,
#                               'place': 'South of the Fiji Islands',
#                               'rms': 1.38,
#                               'sig': 271,
#                               'sources': ',us,',
#                               'status': 'reviewed',
#                               'time': 1388619137530,
#                               'title': 'M 4.2 - South of the Fiji Islands',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',geoserve,nearby-cities,origin,phase-data,tectonic-summary,',
#                               'tz': -720,
#                               'updated': 1394151954000,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/usb000m2w9'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-167.3021, 53.3823, 12.7],
#                             'type': 'Point'},
#                'id': 'ak01421dpqr',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '01421dpqr',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak01421dpqr&format=geojson',
#                               'dmin': None,
#                               'felt': None,
#                               'gap': None,
#                               'ids': ',ak10992884,ak01421dpqr,',
#                               'mag': 1.8,
#                               'magType': 'ml',
#                               'mmi': None,
#                               'net': 'ak',
#                               'nst': None,
#                               'place': '74km SW of Unalaska, Alaska',
#                               'rms': 0.64,
#                               'sig': 50,
#                               'sources': ',ak,ak,',
#                               'status': 'reviewed',
#                               'time': 1388618718598,
#                               'title': 'M 1.8 - 74km SW of Unalaska, Alaska',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',associate,geoserve,nearby-cities,origin,phase-data,tectonic-summary,',
#                               'tz': -540,
#                               'updated': 1558392329375,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak01421dpqr'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [128.3539, -6.1578, 359.16],
#                             'type': 'Point'},
#                'id': 'usb000m2wa',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': 'b000m2wa',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usb000m2wa&format=geojson',
#                               'dmin': 3.439,
#                               'felt': None,
#                               'gap': 82,
#                               'ids': ',usb000m2wa,',
#                               'mag': 4.2,
#                               'magType': 'mb',
#                               'mmi': None,
#                               'net': 'us',
#                               'nst': None,
#                               'place': '269km S of Amahusu, Indonesia',
#                               'rms': 1.05,
#                               'sig': 271,
#                               'sources': ',us,',
#                               'status': 'reviewed',
#                               'time': 1388618653890,
#                               'title': 'M 4.2 - 269km S of Amahusu, Indonesia',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',general-link,geoserve,nearby-cities,origin,phase-data,tectonic-summary,',
#                               'tz': 540,
#                               'updated': 1394151954000,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/usb000m2wa'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-123.1971667, 48.4256667, 11.92],
#                             'type': 'Point'},
#                'id': 'uw60664506',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '60664506',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uw60664506&format=geojson',
#                               'dmin': 0.08557,
#                               'felt': None,
#                               'gap': 115,
#                               'ids': ',uw60664506,',
#                               'mag': 0.64,
#                               'magType': 'md',
#                               'mmi': None,
#                               'net': 'uw',
#                               'nst': 10,
#                               'place': '12km E of Victoria, Canada',
#                               'rms': 0.09,
#                               'sig': 6,
#                               'sources': ',uw,',
#                               'status': 'reviewed',
#                               'time': 1388618284550,
#                               'title': 'M 0.6 - 12km E of Victoria, Canada',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',cap,geoserve,nearby-cities,origin,phase-data,',
#                               'tz': -480,
#                               'updated': 1469215317300,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uw60664506'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-118.4594, 38.5819, 10.7],
#                             'type': 'Point'},
#                'id': 'nn00557596',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '00557596',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nn00557596&format=geojson',
#                               'dmin': 0.068,
#                               'felt': None,
#                               'gap': 193.46,
#                               'ids': ',nn00557596,',
#                               'mag': 0.3,
#                               'magType': 'ml',
#                               'mmi': None,
#                               'net': 'nn',
#                               'nst': 4,
#                               'place': 'Nevada',
#                               'rms': 0.1151,
#                               'sig': 1,
#                               'sources': ',nn,',
#                               'status': 'reviewed',
#                               'time': 1388618225608,
#                               'title': 'M 0.3 - Nevada',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',origin,phase-data,',
#                               'tz': None,
#                               'updated': 1530313185251,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00557596'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-66.1455, 18.3276, 58],
#                             'type': 'Point'},
#                'id': 'pr14001004',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '14001004',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=pr14001004&format=geojson',
#                               'dmin': 0.28027437,
#                               'felt': None,
#                               'gap': 165.6,
#                               'ids': ',pr14001004,usc000lvhk,',
#                               'mag': 2.7,
#                               'magType': 'Md',
#                               'mmi': None,
#                               'net': 'pr',
#                               'nst': 15,
#                               'place': '4km SW of Guaynabo, Puerto Rico',
#                               'rms': 0.23,
#                               'sig': 112,
#                               'sources': ',pr,us,',
#                               'status': 'REVIEWED',
#                               'time': 1388617808800,
#                               'title': 'M 2.7 - 4km SW of Guaynabo, Puerto '
#                                        'Rico',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',cap,geoserve,nearby-cities,origin,phase-data,tectonic-summary,',
#                               'tz': -240,
#                               'updated': 1394151954000,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr14001004'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-115.6021667, 33.1823333, 0.383],
#                             'type': 'Point'},
#                'id': 'ci11408874',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '11408874',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci11408874&format=geojson',
#                               'dmin': 0.01072,
#                               'felt': None,
#                               'gap': 97,
#                               'ids': ',ci11408874,',
#                               'mag': 0.3,
#                               'magType': 'mh',
#                               'mmi': None,
#                               'net': 'ci',
#                               'nst': 10,
#                               'place': '10km SW of Niland, CA',
#                               'rms': 0.06,
#                               'sig': 1,
#                               'sources': ',ci,',
#                               'status': 'reviewed',
#                               'time': 1388617699360,
#                               'title': 'M 0.3 - 10km SW of Niland, CA',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',cap,general-link,geoserve,nearby-cities,origin,phase-data,scitech-link,',
#                               'tz': -480,
#                               'updated': 1457682058070,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci11408874'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-95.659, 17.7689, 120.1],
#                             'type': 'Point'},
#                'id': 'usc000mh9r',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': 'c000mh9r',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usc000mh9r&format=geojson',
#                               'dmin': None,
#                               'felt': None,
#                               'gap': None,
#                               'ids': ',usc000mh9r,',
#                               'mag': 4,
#                               'magType': 'md',
#                               'mmi': None,
#                               'net': 'us',
#                               'nst': None,
#                               'place': '18km ESE of Playa Vicente, Mexico',
#                               'rms': 1.12,
#                               'sig': 246,
#                               'sources': ',us,',
#                               'status': 'reviewed',
#                               'time': 1388617516400,
#                               'title': 'M 4.0 - 18km ESE of Playa Vicente, '
#                                        'Mexico',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',general-link,geoserve,nearby-cities,origin,phase-data,tectonic-summary,',
#                               'tz': -360,
#                               'updated': 1394151954000,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/usc000mh9r'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-116.1108, 36.6771, 0],
#                             'type': 'Point'},
#                'id': 'nn00432852',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '00432852',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nn00432852&format=geojson',
#                               'dmin': 0.021,
#                               'felt': None,
#                               'gap': 148.56,
#                               'ids': ',nn00432852,',
#                               'mag': 0.3,
#                               'magType': 'ml',
#                               'mmi': None,
#                               'net': 'nn',
#                               'nst': 7,
#                               'place': '53km NNW of Pahrump, Nevada',
#                               'rms': 0.0885,
#                               'sig': 1,
#                               'sources': ',nn,',
#                               'status': 'reviewed',
#                               'time': 1388617471115,
#                               'title': 'M 0.3 - 53km NNW of Pahrump, Nevada',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',cap,general-link,geoserve,nearby-cities,origin,phase-data,',
#                               'tz': -480,
#                               'updated': 1530313183570,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00432852'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-118.8601667, 37.5738333, 5.339],
#                             'type': 'Point'},
#                'id': 'nc72134456',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '72134456',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc72134456&format=geojson',
#                               'dmin': 0.02973,
#                               'felt': None,
#                               'gap': 90,
#                               'ids': ',nc72134456,',
#                               'mag': 0.35,
#                               'magType': 'md',
#                               'mmi': None,
#                               'net': 'nc',
#                               'nst': 19,
#                               'place': '12km SE of Mammoth Lakes, California',
#                               'rms': 0.05,
#                               'sig': 2,
#                               'sources': ',nc,',
#                               'status': 'reviewed',
#                               'time': 1388617009820,
#                               'title': 'M 0.4 - 12km SE of Mammoth Lakes, '
#                                        'California',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',cap,geoserve,nearby-cities,origin,phase-data,scitech-link,',
#                               'tz': -480,
#                               'updated': 1486063035481,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc72134456'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-115.3121667, 32.2258333, 8.027],
#                             'type': 'Point'},
#                'id': 'ci11408866',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '11408866',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci11408866&format=geojson',
#                               'dmin': 0.1932,
#                               'felt': None,
#                               'gap': 273,
#                               'ids': ',ci11408866,',
#                               'mag': 1.88,
#                               'magType': 'ml',
#                               'mmi': None,
#                               'net': 'ci',
#                               'nst': 11,
#                               'place': '13km W of Alberto Oviedo Mota, B.C., '
#                                        'MX',
#                               'rms': 0.14,
#                               'sig': 54,
#                               'sources': ',ci,',
#                               'status': 'reviewed',
#                               'time': 1388616646650,
#                               'title': 'M 1.9 - 13km W of Alberto Oviedo Mota, '
#                                        'B.C., MX',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',cap,geoserve,nearby-cities,origin,phase-data,scitech-link,',
#                               'tz': -480,
#                               'updated': 1457662449118,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci11408866'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-122.7453333, 38.7745, -0.44],
#                             'type': 'Point'},
#                'id': 'nc72134451',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '72134451',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc72134451&format=geojson',
#                               'dmin': 0.01102,
#                               'felt': None,
#                               'gap': 68,
#                               'ids': ',nc72134451,',
#                               'mag': 1.24,
#                               'magType': 'md',
#                               'mmi': None,
#                               'net': 'nc',
#                               'nst': 35,
#                               'place': '1km ESE of The Geysers, CA',
#                               'rms': 0.06,
#                               'sig': 24,
#                               'sources': ',nc,',
#                               'status': 'reviewed',
#                               'time': 1388616254500,
#                               'title': 'M 1.2 - 1km ESE of The Geysers, CA',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',focal-mechanism,geoserve,nearby-cities,origin,phase-data,scitech-link,',
#                               'tz': -480,
#                               'updated': 1559857147970,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc72134451'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-118.3738333, 37.3576667, 5.746],
#                             'type': 'Point'},
#                'id': 'nc72134446',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '72134446',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc72134446&format=geojson',
#                               'dmin': 0.07568,
#                               'felt': None,
#                               'gap': 152,
#                               'ids': ',nn00432850,nc72134446,',
#                               'mag': 0.68,
#                               'magType': 'md',
#                               'mmi': None,
#                               'net': 'nc',
#                               'nst': 5,
#                               'place': '2km ESE of Bishop, California',
#                               'rms': 0.05,
#                               'sig': 7,
#                               'sources': ',nn,nc,',
#                               'status': 'reviewed',
#                               'time': 1388616011920,
#                               'title': 'M 0.7 - 2km ESE of Bishop, California',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#                               'tz': -480,
#                               'updated': 1530313184605,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc72134446'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-122.7716675, 38.8033333, 1.12],
#                             'type': 'Point'},
#                'id': 'nc72134441',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '72134441',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc72134441&format=geojson',
#                               'dmin': 0.01622,
#                               'felt': None,
#                               'gap': 111,
#                               'ids': ',nc72134441,',
#                               'mag': 0.52,
#                               'magType': 'md',
#                               'mmi': None,
#                               'net': 'nc',
#                               'nst': 6,
#                               'place': 'Northern California',
#                               'rms': 0.02,
#                               'sig': 4,
#                               'sources': ',nc,',
#                               'status': 'automatic',
#                               'time': 1388615750350,
#                               'title': 'M 0.5 - Northern California',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',nearby-cities,origin,phase-data,scitech-link,',
#                               'tz': None,
#                               'updated': 1486063013394,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc72134441'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-122.8146667, 38.8096667, 2.25],
#                             'type': 'Point'},
#                'id': 'nc72134436',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '72134436',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc72134436&format=geojson',
#                               'dmin': 0.01171,
#                               'felt': None,
#                               'gap': 44,
#                               'ids': ',nc72134436,',
#                               'mag': 1.05,
#                               'magType': 'md',
#                               'mmi': None,
#                               'net': 'nc',
#                               'nst': 42,
#                               'place': '6km NW of The Geysers, California',
#                               'rms': 0.04,
#                               'sig': 17,
#                               'sources': ',nc,',
#                               'status': 'reviewed',
#                               'time': 1388615736120,
#                               'title': 'M 1.1 - 6km NW of The Geysers, '
#                                        'California',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#                               'tz': -480,
#                               'updated': 1486063005672,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc72134436'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [167.2381, -13.7511, 205.98],
#                             'type': 'Point'},
#                'id': 'usb000m2w8',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': 'b000m2w8',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usb000m2w8&format=geojson',
#                               'dmin': 8.309,
#                               'felt': None,
#                               'gap': 94,
#                               'ids': ',usb000m2w8,',
#                               'mag': 4.6,
#                               'magType': 'mb',
#                               'mmi': None,
#                               'net': 'us',
#                               'nst': None,
#                               'place': '36km WNW of Sola, Vanuatu',
#                               'rms': 0.97,
#                               'sig': 326,
#                               'sources': ',us,',
#                               'status': 'reviewed',
#                               'time': 1388615631260,
#                               'title': 'M 4.6 - 36km WNW of Sola, Vanuatu',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',geoserve,nearby-cities,origin,phase-data,tectonic-summary,',
#                               'tz': 660,
#                               'updated': 1394151954000,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/usb000m2w8'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-118.4346, 38.5729, 5.5],
#                             'type': 'Point'},
#                'id': 'nn00557595',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '00557595',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nn00557595&format=geojson',
#                               'dmin': 0.088,
#                               'felt': None,
#                               'gap': 173.49,
#                               'ids': ',nn00557595,',
#                               'mag': 0.8,
#                               'magType': 'ml',
#                               'mmi': None,
#                               'net': 'nn',
#                               'nst': 4,
#                               'place': 'Nevada',
#                               'rms': 0.0336,
#                               'sig': 10,
#                               'sources': ',nn,',
#                               'status': 'reviewed',
#                               'time': 1388615608908,
#                               'title': 'M 0.8 - Nevada',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',origin,phase-data,',
#                               'tz': None,
#                               'updated': 1530313185162,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00557595'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-121.7506667, 46.8501667, 1.436],
#                             'type': 'Point'},
#                'id': 'uw60664496',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '60664496',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uw60664496&format=geojson',
#                               'dmin': 0.01894,
#                               'felt': None,
#                               'gap': 71,
#                               'ids': ',uw60664496,',
#                               'mag': -0.33,
#                               'magType': 'md',
#                               'mmi': None,
#                               'net': 'uw',
#                               'nst': 9,
#                               'place': '27km NNW of Packwood, Washington',
#                               'rms': 0.08,
#                               'sig': 2,
#                               'sources': ',uw,',
#                               'status': 'reviewed',
#                               'time': 1388615267370,
#                               'title': 'M -0.3 - 27km NNW of Packwood, '
#                                        'Washington',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',general-link,geoserve,nearby-cities,origin,phase-data,',
#                               'tz': -480,
#                               'updated': 1469215317030,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uw60664496'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-116.7493333, 33.7068333, 17.148],
#                             'type': 'Point'},
#                'id': 'ci11408858',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '11408858',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci11408858&format=geojson',
#                               'dmin': 0.02963,
#                               'felt': None,
#                               'gap': 165,
#                               'ids': ',ci11408858,',
#                               'mag': 0.53,
#                               'magType': 'ml',
#                               'mmi': None,
#                               'net': 'ci',
#                               'nst': 15,
#                               'place': '5km SW of Idyllwild, CA',
#                               'rms': 0.04,
#                               'sig': 4,
#                               'sources': ',ci,',
#                               'status': 'reviewed',
#                               'time': 1388615009140,
#                               'title': 'M 0.5 - 5km SW of Idyllwild, CA',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',cap,general-link,geoserve,nearby-cities,origin,phase-data,scitech-link,',
#                               'tz': -480,
#                               'updated': 1457735530566,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci11408858'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-118.4288333, 37.6036667, 7.766],
#                             'type': 'Point'},
#                'id': 'nc72134431',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '72134431',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc72134431&format=geojson',
#                               'dmin': 0.05676,
#                               'felt': None,
#                               'gap': 73,
#                               'ids': ',nc72134431,nn00432849,ci11408850,',
#                               'mag': 2.51,
#                               'magType': 'md',
#                               'mmi': None,
#                               'net': 'nc',
#                               'nst': 42,
#                               'place': '24km N of Dixon Lane-Meadow Creek, '
#                                        'California',
#                               'rms': 0.06,
#                               'sig': 97,
#                               'sources': ',nc,nn,ci,',
#                               'status': 'reviewed',
#                               'time': 1388614835770,
#                               'title': 'M 2.5 - 24km N of Dixon Lane-Meadow '
#                                        'Creek, California',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',cap,focal-mechanism,general-link,geoserve,nearby-cities,origin,phase-data,scitech-link,',
# ...
#                               'status': 'reviewed',
#                               'time': 1388537642935,
#                               'title': 'M 2.3 - 87km SE of Nikolski, Alaska',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',associate,geoserve,nearby-cities,origin,phase-data,tectonic-summary,',
#                               'tz': -660,
#                               'updated': 1558392308429,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0141nuxdx'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-116.4728333, 33.4625, 12.559],
#                             'type': 'Point'},
#                'id': 'ci11408434',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '11408434',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci11408434&format=geojson',
#                               'dmin': 0.1128,
#                               'felt': None,
#                               'gap': 153,
#                               'ids': ',ci11408434,',
#                               'mag': 0.1,
#                               'magType': 'ml',
#                               'mmi': None,
#                               'net': 'ci',
#                               'nst': 15,
#                               'place': '21km ESE of Anza, CA',
#                               'rms': 0.1,
#                               'sig': 0,
#                               'sources': ',ci,',
#                               'status': 'reviewed',
#                               'time': 1388537639130,
#                               'title': 'M 0.1 - 21km ESE of Anza, CA',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',cap,general-link,geoserve,nearby-cities,origin,phase-data,scitech-link,',
#                               'tz': -480,
#                               'updated': 1457762408379,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci11408434'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-144.7523, 63.236, 11.7],
#                             'type': 'Point'},
#                'id': 'ak0141ntf85',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '0141ntf85',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0141ntf85&format=geojson',
#                               'dmin': None,
#                               'felt': None,
#                               'gap': None,
#                               'ids': ',ak10992831,ak0141ntf85,',
#                               'mag': 1.3,
#                               'magType': 'ml',
#                               'mmi': None,
#                               'net': 'ak',
#                               'nst': None,
#                               'place': '74km SSE of Deltana, Alaska',
#                               'rms': 0.57,
#                               'sig': 26,
#                               'sources': ',ak,ak,',
#                               'status': 'reviewed',
#                               'time': 1388537221015,
#                               'title': 'M 1.3 - 74km SSE of Deltana, Alaska',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',associate,geoserve,nearby-cities,origin,phase-data,tectonic-summary,',
#                               'tz': -540,
#                               'updated': 1558392307639,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0141ntf85'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-122.5188333, 46.0926667, 13.97],
#                             'type': 'Point'},
#                'id': 'uw60664276',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '60664276',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uw60664276&format=geojson',
#                               'dmin': 0.08565,
#                               'felt': None,
#                               'gap': 182,
#                               'ids': ',uw60664276,',
#                               'mag': 0.22,
#                               'magType': 'md',
#                               'mmi': None,
#                               'net': 'uw',
#                               'nst': 9,
#                               'place': '21km NNW of Amboy, Washington',
#                               'rms': 0.1,
#                               'sig': 1,
#                               'sources': ',uw,',
#                               'status': 'reviewed',
#                               'time': 1388536764680,
#                               'title': 'M 0.2 - 21km NNW of Amboy, Washington',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',cap,general-link,geoserve,nearby-cities,origin,phase-data,',
#                               'tz': -480,
#                               'updated': 1469215315430,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uw60664276'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-122.7776642, 38.8320007, 0.187],
#                             'type': 'Point'},
#                'id': 'nc72133846',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '72133846',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc72133846&format=geojson',
#                               'dmin': 0.006306,
#                               'felt': None,
#                               'gap': 90,
#                               'ids': ',nc72133846,',
#                               'mag': 1.07,
#                               'magType': 'md',
#                               'mmi': None,
#                               'net': 'nc',
#                               'nst': 14,
#                               'place': '4km WNW of Cobb, California',
#                               'rms': 0.05,
#                               'sig': 18,
#                               'sources': ',nc,',
#                               'status': 'automatic',
#                               'time': 1388536602470,
#                               'title': 'M 1.1 - 4km WNW of Cobb, California',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',geoserve,nearby-cities,origin,phase-data,',
#                               'tz': -480,
#                               'updated': 1486062284045,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc72133846'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-155.0353333, 19.3246667, 1.294],
#                             'type': 'Point'},
#                'id': 'hv60614021',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '60614021',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv60614021&format=geojson',
#                               'dmin': None,
#                               'felt': None,
#                               'gap': 207,
#                               'ids': ',hv60614021,',
#                               'mag': 2.08,
#                               'magType': 'ml',
#                               'mmi': None,
#                               'net': 'hv',
#                               'nst': 38,
#                               'place': '18 km SE of Fern Forest, Hawaii',
#                               'rms': 0.14,
#                               'sig': 67,
#                               'sources': ',hv,',
#                               'status': 'reviewed',
#                               'time': 1388536590280,
#                               'title': 'M 2.1 - 18 km SE of Fern Forest, '
#                                        'Hawaii',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',cap,geoserve,nearby-cities,origin,phase-data,',
#                               'tz': -600,
#                               'updated': 1594067950160,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv60614021'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-153.0185, 60.0872, 105.8],
#                             'type': 'Point'},
#                'id': 'ak0141nol21',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '0141nol21',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0141nol21&format=geojson',
#                               'dmin': None,
#                               'felt': None,
#                               'gap': None,
#                               'ids': ',ak10992830,ak0141nol21,',
#                               'mag': 2,
#                               'magType': 'ml',
#                               'mmi': None,
#                               'net': 'ak',
#                               'nst': None,
#                               'place': '46km SSW of Redoubt Volcano, Alaska',
#                               'rms': 0.77,
#                               'sig': 62,
#                               'sources': ',ak,ak,',
#                               'status': 'reviewed',
#                               'time': 1388535883771,
#                               'title': 'M 2.0 - 46km SSW of Redoubt Volcano, '
#                                        'Alaska',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',associate,geoserve,nearby-cities,origin,phase-data,tectonic-summary,',
#                               'tz': -540,
#                               'updated': 1558392307098,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0141nol21'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-122.8435, 38.8216667, 2.14],
#                             'type': 'Point'},
#                'id': 'nc72133841',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '72133841',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc72133841&format=geojson',
#                               'dmin': 0.007207,
#                               'felt': None,
#                               'gap': 65,
#                               'ids': ',nc72133841,',
#                               'mag': 0.57,
#                               'magType': 'md',
#                               'mmi': None,
#                               'net': 'nc',
#                               'nst': 30,
#                               'place': '9km WNW of The Geysers, California',
#                               'rms': 0.04,
#                               'sig': 5,
#                               'sources': ',nc,',
#                               'status': 'reviewed',
#                               'time': 1388535010970,
#                               'title': 'M 0.6 - 9km WNW of The Geysers, '
#                                        'California',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#                               'tz': -480,
#                               'updated': 1486062277926,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc72133841'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-175.5282, -18.4965, 217.9],
#                             'type': 'Point'},
#                'id': 'usc000lv5j',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': 'c000lv5j',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usc000lv5j&format=geojson',
#                               'dmin': 5.337,
#                               'felt': None,
#                               'gap': 41,
#                               'ids': ',usc000lv5j,',
#                               'mag': 4.5,
#                               'magType': 'mb',
#                               'mmi': None,
#                               'net': 'us',
#                               'nst': None,
#                               'place': '163km W of Neiafu, Tonga',
#                               'rms': 0.6,
#                               'sig': 312,
#                               'sources': ',us,',
#                               'status': 'reviewed',
#                               'time': 1388534728830,
#                               'title': 'M 4.5 - 163km W of Neiafu, Tonga',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',cap,geoserve,nearby-cities,origin,phase-data,tectonic-summary,',
#                               'tz': -720,
#                               'updated': 1394151953000,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/usc000lv5j'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [120.2389, 19.0868, 10.07],
#                             'type': 'Point'},
#                'id': 'usc000lv5e',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': 'c000lv5e',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usc000lv5e&format=geojson',
#                               'dmin': 3.794,
#                               'felt': None,
#                               'gap': 29,
#                               'ids': ',usc000lv5e,',
#                               'mag': 5.1,
#                               'magType': 'mb',
#                               'mmi': None,
#                               'net': 'us',
#                               'nst': None,
#                               'place': '76km NNW of Davila, Philippines',
#                               'rms': 0.85,
#                               'sig': 400,
#                               'sources': ',us,',
#                               'status': 'reviewed',
#                               'time': 1388534476610,
#                               'title': 'M 5.1 - 76km NNW of Davila, '
#                                        'Philippines',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',cap,general-link,geoserve,nearby-cities,origin,phase-data,tectonic-summary,',
#                               'tz': 480,
#                               'updated': 1394151953000,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/usc000lv5e'},
#                'type': 'Feature'}],
#  'metadata': {'api': '1.10.3',
#               'count': 325,
#               'generated': 1615067240000,
#               'status': 200,
#               'title': 'USGS Earthquakes',
#               'url': 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2014-01-01&endtime=2014-01-02&eventtype=earthquake'},
#  'type': 'FeatureCollection'}

# %%
# create list variables to contain data
alert = []
cdi = []
code = []
detail = []
dmin = []
mag = []
magType = []
ids = []
felt = []
gap = []
mmi = []
net = []
nst = []
place = []
rms = []
sig = []
sources = []
status = []
sources = []
time = []
title = []
tsunami = []
types = []
tz = []
updated = []
url = []

# %%
# append all lists
for x in data["features"]:
    alert.append(x["properties"]["alert"])
    
    cdi.append(x["properties"]["cdi"])
    
    code.append(x["properties"]["code"])
    
    detail.append(x["properties"]["detail"])
    
    dmin.append(x["properties"]["dmin"])

    mag.append(x["properties"]["mag"])

    magType.append(x["properties"]["magType"])

    ids.append(x["properties"]["ids"])

    felt.append(x["properties"]["felt"])
    
    gap.append(x["properties"]["gap"])
    
    mmi.append(x["properties"]["mmi"])
    
    net.append(x["properties"]["net"])
    
    nst.append(x["properties"]["nst"])
    
    place.append(x["properties"]["place"])
    
    rms.append(x["properties"]["rms"])
    
    sig.append(x["properties"]["sig"])
    
    sources.append(x["properties"]["sources"])
    
    status.append(x["properties"]["status"])
    
    time.append(x["properties"]["time"])
    
    title.append(x["properties"]["title"])
    
    tsunami.append(x["properties"]["tsunami"])
    
    types.append(x["properties"]["type"])
    
    tz.append(x["properties"]["tz"])
    
    updated.append(x["properties"]["updated"])
    
    url.append(x["properties"]["url"])

# %%
# sanity check - prints a few lists to ensure code ran

print(source)
# Out:
# [',ci,', ',ak,ak,', ',ak,ak,', ',ak,ak,', ',us,', ',nc,', ',nc,', ',ci,', ',nn,', ',us,', ',ak,ak,', ',us,', ',uw,', ',nn,', ',pr,us,', ',ci,', ',us,', ',nn,', ',nc,', ',ci,', ',nc,', ',nn,nc,', ',nc,', ',nc,', ',us,', ',nn,', ',uw,', ',ci,', ',nc,nn,ci,', ',nc,', ',nn,', ',nc,', ',ci,', ',nc,', ',nc,', ',nc,', ',us,', ',ak,ak,', ',nc,', ',ak,ak,', ',nc,', ',nc,', ',ak,ak,', ',nc,', ',nn,', ',ak,ak,', ',us,', ',nc,', ',ci,', ',us,', ',nc,', ',nn,', ',us,', ',ci,', ',ci,', ',nn,', ',ak,ak,', ',ak,ak,', ',hv,', ',nc,', ',nc,', ',uw,', ',nc,', ',ci,', ',nc,', ',nc,', ',nn,nc,', ',ci,', ',ak,ak,', ',ci,', ',nn,', ',ak,ak,', ',nc,', ',us,', ',ak,ak,', ',ci,', ',nc,', ',nc,', ',nc,', ',nc,', ',ak,ak,', ',ci,', ',ld,', ',ak,ak,', ',nn,', ',nc,', ',ci,', ',ak,ak,', ',nc,', ',nc,', ',nn,', ',nc,', ',nc,', ',nc,', ',ci,', ',ci,', ',ci,', ',us,', ',nc,', ',ci,', ',uw,', ',us,ak,', ',nc,', ',ci,', ',ak,ak,', ',ak,ak,', ',ci,', ',hv,', ',hv,', ',nc,', ',uw,', ',pr,', ',us,', ',nc,', ',nc,', ',nc,', ',hv,', ',nc,', ',us,', ',nc,', ',us,', ',pt,at,us,', ',ci,', ',ci,nc,us,', ',ci,', ',ak,ak,', ',nc,', ',ak,ak,', ',us,', ',nc,', ',us,', ',nc,nn,', ',nn,', ',nc,', ',us,', ',us,', ',nc,', ',ak,ak,', ',pr,', ',ci,', ',ak,ak,', ',ak,ak,', ',us,', ',ci,', ',ak,', ',nc,', ',ak,', ',ak,ak,', ',pr,us,', ',ak,ak,', ',nc,', ',ak,ak,', ',ak,ak,', ',nc,', ',ak,ak,', ',us,', ',nc,', ',ak,', ',ci,', ',us,', ',nc,', ',uu,', ',mb,', ',ci,', ',uw,', ',nc,', ',ci,', ',nc,', ',us,', ',ci,', ',us,', ',ak,ak,', ',us,', ',us,', ',us,', ',nc,', ',ak,', ',ak,ak,', ',ak,us,ak,', ',nn,', ',ci,', ',uu,', ',nc,', ',uu,', ',nn,', ',us,ak,', ',us,', ',ak,ak,', ',us,ak,', ',nc,', ',nc,', ',ci,', ',nc,', ',ak,ak,', ',ak,', ',ak,ak,', ',pr,us,', ',ak,ak,', ',ci,', ',nn,', ',ak,us,ak,', ',uu,', ',nc,', ',ak,us,ak,', ',nn,', ',nc,', ',nc,', ',nc,', ',nc,', ',ci,', ',nn,', ',ci,', ',nc,', ',nc,', ',nn,', ',us,', ',ci,', ',nc,', ',nc,', ',ci,', ',nc,', ',ak,', ',nn,', ',nc,', ',us,', ',nc,', ',nc,', ',nc,', ',ci,', ',nc,', ',nc,', ',nn,', ',us,', ',us,', ',ci,', ',ci,', ',nc,', ',nc,', ',ci,', ',ci,', ',us,', ',nn,', ',uu,', ',ci,', ',ci,', ',nn,', ',nc,', ',nc,', ',nn,', ',ci,', ',ak,ak,', ',ci,', ',nc,', ',nn,', ',us,', ',uu,us,', ',nc,', ',us,', ',us,', ',nc,', ',uw,', ',ci,', ',ak,ak,', ',nc,', ',ci,', ',nn,', ',ak,ak,', ',ak,us,ak,', ',nc,', ',nn,', ',ci,', ',nc,', ',nc,', ',ak,ak,', ',nm,nm,', ',nc,', ',ci,', ',nc,', ',us,', ',nc,', ',nc,', ',nc,', ',uu,', ',ci,', ',nc,', ',nc,', ',nc,', ',us,', ',nc,', ',mb,', ',mb,', ',nc,', ',ak,ak,', ',nc,', ',nc,', ',nn,', ',ak,ak,', ',nn,', ',nc,', ',ak,ak,', ',nc,', ',nc,', ',ci,', ',hv,', ',hv,', ',nc,', ',nc,', ',nc,', ',nc,', ',uu,', ',us,', ',ak,us,ak,', ',us,', ',ci,', ',ak,ak,', ',ak,ak,', ',ci,', ',ak,ak,', ',uw,', ',nc,', ',hv,', ',ak,ak,', ',nc,', ',us,', ',us,']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-90a4500e67ae> in <module>
#       1 # sanity check - prints a few lists to ensure code ran
#       2
# ----> 3 print(sources).limit(5)
#
# AttributeError: 'NoneType' object has no attribute 'limit'

# %%
# construct dataframes for each list in Pandas

alert_df = pd.DataFrame({"Alert": alert})
cdi_df = pd.DataFrame({"CDI": cdi})
code_df = pd.DataFrame({"Code": code})
detail_df = pd.DataFrame({"Detail": detail})
dmin_df = pd.DataFrame({"Depth Min": dmin})
mag_df = pd.DataFrame({"Magnitude":mag})
magType_df = pd.DataFrame({"Waveform":magType})
ids_df = pd.DataFrame({"ID":ids})
felt_df = pd.DataFrame({"Felt":felt})
gap_df = pd.DataFrame({"Gap":gap})
mmi_df = pd.DataFrame({"MMI":mmi})
net_df = pd.DataFrame({"Net":net})
nst_df = pd.DataFrame({"NST":nst})
place_df = pd.DataFrame({"Place":place})
rms_df = pd.DataFrame({"RMS":rms})
sig_df = pd.DataFrame({"Sig":sig})
sources_df = pd.DataFrame({"Sources":sources})
status_df = pd.DataFrame({"Status":status})
time_df = pd.DataFrame({"Time":time})
title_df = pd.DataFrame({"Title":title})
tsunami_df = pd.DataFrame({"Tsunami":tsunami})
types_df = pd.DataFrame({"Type":types})
tz_df = pd.DataFrame({"TZ":tz})
updated_df = pd.DataFrame({"Updated":updated})
url_df = pd.DataFrame({"URL":url})

# %%
# sanity check - check dataFrames. 

tsunami_df.head()
# Out:
#    Tsunami
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
# merges dataframes made above

ses_df = pd.DataFrame(dmin_df)
ses_df = ses_df.merge(mag_df, "inner", right_index=True, left_index=True)
ses_df = ses_df.merge(magType_df, "inner", right_index=True, left_index=True)
ses_df = ses_df.merge(alert_df, "inner", right_index=True, left_index=True)
ses_df = ses_df.merge(cdi_df, "inner", right_index=True, left_index=True)
ses_df = ses_df.merge(code_df, "inner", right_index=True, left_index=True)
ses_df = ses_df.merge(detail_df, "inner", right_index=True, left_index=True)
ses_df = ses_df.merge(ids_df, "inner", right_index=True, left_index=True)
ses_df = ses_df.merge(felt_df, "inner", right_index=True, left_index=True)
ses_df = ses_df.merge(gap_df, "inner", right_index=True, left_index=True)
ses_df = ses_df.merge(mmi_df, "inner", right_index=True, left_index=True)
ses_df = ses_df.merge(net_df, "inner", right_index=True, left_index=True)
ses_df = ses_df.merge(nst_df, "inner", right_index=True, left_index=True)
ses_df = ses_df.merge(rms_df, "inner", right_index=True, left_index=True)
ses_df = ses_df.merge(place_df, "inner", right_index=True, left_index=True)
ses_df = ses_df.merge(sig_df, "inner", right_index=True, left_index=True)
ses_df = ses_df.merge(sources_df, "inner", right_index=True, left_index=True)
ses_df = ses_df.merge(status_df, "inner", right_index=True, left_index=True)
ses_df = ses_df.merge(time_df, "inner", right_index=True, left_index=True)
ses_df = ses_df.merge(title_df, "inner", right_index=True, left_index=True)
ses_df = ses_df.merge(tsunami_df, "inner", right_index=True, left_index=True)
ses_df = ses_df.merge(types_df, "inner", right_index=True, left_index=True)
ses_df = ses_df.merge(tz_df, "inner", right_index=True, left_index=True)
ses_df = ses_df.merge(updated_df, "inner", right_index=True, left_index=True)
ses_df = ses_df.merge(url_df, "inner", right_index=True, left_index=True)

# %%
# check final dataframe

ses_df.head()
# Out:
#    Depth Min  Magnitude Waveform Alert  CDI       Code  \
# 0    0.06729       1.29       ml  None  NaN   11408890
# 1        NaN       1.10       ml  None  NaN  01421ig3u
# 2        NaN       1.20       ml  None  NaN  01421i2zj
# 3        NaN       1.40       ml  None  NaN  01421heui
# 4        NaN       4.00       ml  None  NaN   c000mnnn
#
#                                               Detail  \
# 0  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#                          ID  Felt   Gap  ...  Sig  Sources    Status  \
# 0              ,ci11408890,   NaN  51.0  ...   26     ,ci,  reviewed
# 1  ,ak10992887,ak01421ig3u,   NaN   NaN  ...   19  ,ak,ak,  reviewed
# 2  ,ak10934318,ak01421i2zj,   NaN   NaN  ...   22  ,ak,ak,  reviewed
# 3  ,ak10992885,ak01421heui,   NaN   NaN  ...   30  ,ak,ak,  reviewed
# 4              ,usc000mnnn,   NaN   NaN  ...  246     ,us,  reviewed
#
#             Time                                  Title  Tsunami        Type  \
# 0  1388620296020      M 1.3 - 10km SSW of Idyllwild, CA        0  earthquake
# 1  1388620046501  M 1.1 - 117km NW of Talkeetna, Alaska        0  earthquake
# 2  1388619956476    M 1.2 - 6km SSW of Big Lake, Alaska        0  earthquake
# 3  1388619763623   M 1.4 - 63km NW of Talkeetna, Alaska        0  earthquake
# 4  1388619735000    M 4.0 - 27km WNW of Coquimbo, Chile        0  earthquake
#
#       TZ        Updated                                                URL
# 0 -480.0  1457728844428  https://earthquake.usgs.gov/earthquakes/eventp...
# 1 -540.0  1558392330681  https://earthquake.usgs.gov/earthquakes/eventp...
# 2 -540.0  1558392330249  https://earthquake.usgs.gov/earthquakes/eventp...
# 3 -540.0  1558392329762  https://earthquake.usgs.gov/earthquakes/eventp...
# 4 -300.0  1394151954000  https://earthquake.usgs.gov/earthquakes/eventp...
#
# [5 rows x 25 columns]
